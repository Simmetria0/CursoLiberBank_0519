# %% [markdown]
# -------------
#  # **Data Visualization with python**
#
#  ## **Diego Tuccillo**
#
#  ### Part I : Matplotlib
#
#  ![alternate text](https://matplotlib.org/_static/logo2.png)
#
# *Matplotlib is the grandfather of python visualization packages. It is extremely powerful but with that power comes complexity. You can typically do anything you need using matplotlib but it is not always so easy to figure out.*
#
# -------------

# %% [markdown]
# ###  (A)  Basic Plotting with Matplotlib

# %%
#import library
import matplotlib.pyplot as plt

# %%
#Line plot price of 1 Gb

years = [1981, 1987, 1990, 1994, 1997, 2000, 2004, 2010]
dollars= [300000, 50000, 10000, 1000, 100, 10, 1, 0.1]
plt.plot(years, dollars)

# %%
#let's add title, axes labels, and label range

plt.title("Correlation price Gb over years!")
plt.ylabel("price of 1 Gb hard disk")
plt.xlabel("years")
plt.xlim(1980, 2016)
plt.ylim(0, 330000)
plt.plot(years, dollars)

# %% [markdown]
# -------------
# ### Exercise 1) Change color and type of line. You have to add these options in plt.plot:
# color='green',
# marker='o',
# linewidth=2.5,
# linestyle='dotted'
#
# Other markers: "." 	point ;  "," 	pixel ; "o" circle ; "v" triangle_down
#
# You can find more information here:
# (http://matplotlib.org/api/markers_api.html#module-matplotlib.markers)
#
# Other linestyle: '-' or 'solid' 	solid line; '--' or 'dashed' dashed line ;'-.' or 'dashdot' 	dash-dotted line
#
# -----------

# %%
# You can display the plot or you can save it
#plt.show()
#plt.close()
#or to save it
plt.savefig("/Users/simmetria0/Desktop/primoPlot.png")

# %% [markdown]
# ### Does it look fine?
#
# ### Try now:

# %%
plt.plot(years, dollars, color='green', marker='o', linewidth=2.5, linestyle='dotted')
plt.savefig("/Users/simmetria0/Desktop/primoPlot.png")

# %% [markdown]
# ----------
# ### Exercise 2) Tell me why the first time it didn't work
# ------------

# %%
#Some options when you save a plot:

plt.plot(years, dollars, color='green', marker='o', linewidth=2.5, linestyle='dotted')
plt.savefig("/Users/simmetria0/Desktop/secondo.pdf", bbox_inches='tight')

# %% [markdown]
# ----------
# ### Exercise 3) Try other formats:
# #Most backends support png, pdf, ps, eps and svg.
#
# Try other options:
# savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches=None, pad_inches=0.1,frameon=None)
#
# ------------

# %%
#size of the figure:
fig, ax = plt.subplots()
plt.title("My 3rd plot!", fontsize=15)
plt.ylabel("price of 1 Gb hard disk", fontsize=13)
plt.xlabel("years", fontsize=13)
plt.xlim(1980, 2000)
plt.ylim(0, 330000)
plt.plot(years, dollars, color='green', marker='o', linewidth=2.5, linestyle='dotted')
fig.set_size_inches(8,7)
plt.savefig("/Users/simmetria0/Desktop/terzo.pdf", bbox_inches='tight')

# %% [markdown]
# ------
#
# ### (B)  Bar charts, histograms
#
# ----

# %%
#bar chart (type one: bar)
equipos = ["Valencia", "FC Barcelona", "Atletico Madrid","Real Madrid",  "Athletic Bilbao"]
Titulos_Liga = [6, 24, 10, 33, 8]
xs = [0., 1., 2., 3., 4.]
plt.bar(xs, Titulos_Liga, color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
#Let's improve it

plt.ylabel("# Ligas")
plt.title("Ganadores Liga Esp.")
plt.bar(xs, Titulos_Liga, color='green')
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], equipos)
# Out:
# ([<matplotlib.axis.XTick at 0x11cc810f0>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#Not great right? two problems: 1) names are superposed, we can solve it like this:
plt.ylabel("# Ligas")
plt.title("Ganadores Liga Esp.")
plt.bar(xs, Titulos_Liga, color='green')
plt.xticks([0.1, 1., 2., 3., 4.], equipos, rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x11ce07588>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#problem 2, But the team names atre not centered! This is because by default the binwidth = 0.8. We can solve in this way:
xs = [i + 0.1 for i, _ in enumerate(equipos)]
plt.ylabel("# Ligas")
plt.title("Ganadores Liga Esp.")
plt.bar(xs, Titulos_Liga, color='green')
plt.xticks([j + 0.1 for j, _ in enumerate(equipos)], equipos, rotation=30)
# Out:
# ([<matplotlib.axis.XTick at 0x1221a49e8>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
# (3)Histogran
import numpy as np

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)
print (x[:10])
#generates an array filled with random floats sampled from a univariate “normal” (Gaussian) distribution of mean 0 and variance 1
# ed in generale: sigma * np.random.randn(...) + mu

# the histogram of the data
plt.hist(x, bins = 'auto')
# Out:
# [ 89.69993574 136.65392642 112.45568591  96.58521928 108.86897772
#   79.04858396  98.90979293 102.33904376  90.14830764  96.46947028]
# (array([  4.,   1.,   1.,   1.,   2.,   8.,   6.,  16.,  18.,  22.,  38.,
#          61.,  51.,  74.,  89., 134., 142., 171., 189., 241., 271., 306.,
#         342., 388., 410., 432., 467., 484., 471., 522., 490., 470., 489.,
#         446., 379., 345., 318., 296., 272., 212., 182., 157., 136., 109.,
#          83.,  66.,  57.,  38.,  28.,  21.,  17.,   8.,   8.,   5.,   3.,
#           1.,   0.,   1.,   0.,   0.,   1.]),
#  array([ 45.66967118,  47.52465818,  49.37964517,  51.23463217,
#          53.08961917,  54.94460617,  56.79959317,  58.65458017,
#          60.50956717,  62.36455417,  64.21954117,  66.07452817,
#          67.92951517,  69.78450217,  71.63948916,  73.49447616,
#          75.34946316,  77.20445016,  79.05943716,  80.91442416,
#          82.76941116,  84.62439816,  86.47938516,  88.33437216,
# ...

# %% [markdown]
# ### Question: so, what's the difference between barchart and histogram?

# %%
#let's make it prettier:

plt.hist(x, density=1, bins = 'auto', facecolor='green', alpha=0.75) #bins=20,
# Out:
# (array([2.15634934e-04, 5.39087336e-05, 5.39087336e-05, 5.39087336e-05,
#         1.07817467e-04, 4.31269869e-04, 3.23452402e-04, 8.62539738e-04,
#         9.70357205e-04, 1.18599214e-03, 2.04853188e-03, 3.28843275e-03,
#         2.74934541e-03, 3.98924629e-03, 4.79787729e-03, 7.22377030e-03,
#         7.65504017e-03, 9.21839345e-03, 1.01887507e-02, 1.29920048e-02,
#         1.46092668e-02, 1.64960725e-02, 1.84367869e-02, 2.09165886e-02,
#         2.21025808e-02, 2.32885729e-02, 2.51753786e-02, 2.60918271e-02,
#         2.53910135e-02, 2.81403589e-02, 2.64152795e-02, 2.53371048e-02,
#         2.63613707e-02, 2.40432952e-02, 2.04314100e-02, 1.85985131e-02,
#         1.71429773e-02, 1.59569852e-02, 1.46631755e-02, 1.14286515e-02,
#         9.81138952e-03, 8.46367118e-03, 7.33158777e-03, 5.87605196e-03,
#         4.47442489e-03, 3.55797642e-03, 3.07279782e-03, 2.04853188e-03,
#         1.50944454e-03, 1.13208341e-03, 9.16448471e-04, 4.31269869e-04,
# ...

# %% [markdown]
# ### Question: What's the density=1 option?

# %%
#alpha suseful in case of more distributions:
mu1, sigma1 = 120, 10
y = mu1 + sigma1*np.random.randn(10000)
bins = 100
plt.hist(x, bins, facecolor='green', alpha=0.3)
plt.hist(y, bins, facecolor='blue', alpha=0.4)
# Out:
# (array([  1.,   0.,   0.,   0.,   2.,   0.,   2.,   0.,   1.,   1.,   4.,
#           2.,   3.,   3.,   8.,   7.,   9.,   7.,  16.,  21.,  25.,  21.,
#          38.,  31.,  36.,  45.,  43.,  55.,  71.,  72.,  79., 119., 102.,
#         127., 134., 143., 151., 155., 194., 194., 214., 202., 232., 225.,
#         266., 289., 241., 284., 269., 278., 272., 305., 302., 291., 278.,
#         282., 294., 265., 264., 245., 254., 232., 240., 205., 185., 173.,
#         168., 153., 126., 133., 118., 101.,  90.,  79.,  65.,  68.,  54.,
#          55.,  49.,  34.,  34.,  29.,  20.,  15.,  22.,  15.,  15.,  11.,
#           5.,  10.,   7.,   2.,   4.,   2.,   3.,   0.,   3.,   0.,   0.,
#           1.]), array([ 82.13419322,  82.86571399,  83.59723477,  84.32875554,
#          85.06027632,  85.79179709,  86.52331786,  87.25483864,
#          87.98635941,  88.71788019,  89.44940096,  90.18092174,
#          90.91244251,  91.64396329,  92.37548406,  93.10700484,
# ...

# %%
#you can choose whatever bins you want, also not uniform:
plt.hist(x, bins=[50,80,90,100,110,150])
# Out:
# (array([ 931., 1618., 2503., 2436., 2508.]),
#  array([ 50,  80,  90, 100, 110, 150]),
#  <a list of 5 Patch objects>)

# %%
#when you put a number, bins decide the binwidth. When you put multiple numbers, it's the ranging limit. If you wnat a fixed costumixed binwidth:
binwidth = 15
print(np.arange(min(x), max(x) + binwidth, binwidth))
plt.hist(x, bins=np.arange(min(x), max(x) + binwidth, binwidth))
# Out:
# [ 45.66967118  60.66967118  75.66967118  90.66967118 105.66967118
#  120.66967118 135.66967118 150.66967118 165.66967118]
# (array([4.000e+01, 5.070e+02, 2.134e+03, 3.796e+03, 2.676e+03, 7.680e+02,
#         7.700e+01, 2.000e+00]),
#  array([ 45.66967118,  60.66967118,  75.66967118,  90.66967118,
#         105.66967118, 120.66967118, 135.66967118, 150.66967118,
#         165.66967118]),
#  <a list of 8 Patch objects>)

# %%
#Now let's test VISUALLY if our data are normally distributed:

n, bins, patches = plt.hist(x, 50, density=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
import scipy.stats as sci
y = sci.norm.pdf(bins, mu, sigma)

l = plt.plot(bins, y, 'r--', linewidth=2)

# %% [markdown]
# ### Exercise: Improve the visual Impact.
# Add:
#     - x, y label
#     - title, and try this:
#       plt.title(r'$\mathrm{Histogram:}\ \mu=100,\ \sigma=15$')
#     - try plt.axis([40, 160, 0, 0.03])
#     - plt.grid(True)

# %% [markdown]
# ------
#
# ### (C)  Scatterplots
#
# ----

# %%
friendsOnFB = [20, 140, 165, 178, 63, 191, 364, 260, 234, 567, 480]
#minutes on FB for day
minutes = [10, 115, 270, 130, 80, 162, 230, 105, 245, 480, 320]
plt.scatter(friendsOnFB, minutes)

# %%
#  let's put names on the points:
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'l', 'm']
for label, friend_count, minute_count in zip(labels, friendsOnFB, minutes):
    plt.annotate(label,
    xy=(friend_count, minute_count), # put the label with its point
    xytext=(5, -5), # but slightly offset
    textcoords='offset points')
    
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on FB")
plt.scatter(friendsOnFB, minutes)
plt.show()

# %% [markdown]
# ------
#
# ### (D)  More Plots
#
# ----

# %%
#Pie chart
plt.pie([0.95, 0.05], labels=["aburridos de los plots", "los q quieren mas!"])
plt.axis("equal")
plt.show()

# %%
#Bubble charts. Bubble charts display data as a cluster of circles. The required data to create bubble chart needs to have the xy coordinates, 
#size of the bubble and the colour of the bubbles. The colours can be supplied by the library itself.
 
# create data
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)
colors = np.random.rand(40) 
# use the scatter function
plt.scatter(x, y, s=z*1000,c=colors)
plt.show()

# %% [markdown]
# ---
#
# ### (E) More Advanced
#
# ---

# %%
#Box plots and subplot function:
# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x122b42390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a24f9ada0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x122b420f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a24f9a080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a24f9a780>],
#  'means': []}

# %%
#Understanding plt.subplots() Notation.
# is more customizable and comes in handy as graphs become more complex.
fig, ax = plt.subplots()

# %% [markdown]
# Above, we took advantage of iterable unpacking to assign a separate variable to each of the two results of plt.subplots(). Notice that we didn’t pass arguments to subplots() here. The default call is subplots(nrows=1, ncols=1). Consequently, ax is a single AxesSubplot object:

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# We can call its instance methods to manipulate the plot. Let’s illustrate with a stacked area graph of three time series:

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng

fig, ax = plt.subplots(figsize=(5, 3))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])
fig.tight_layout()

# %% [markdown]
# Here’s what’s going on above:
#
# After creating three random time series, we defined one Figure (fig) containing one Axes (a plot, ax).
#
# We call methods of ax directly to create a stacked area chart and to add a legend, title, and y-axis label. Under the object-oriented approach, it’s clear that all of these are attributes of ax.
#
# tight_layout() applies to the Figure object as a whole to clean up whitespace padding.

# %%
#Let’s look at an example with multiple subplots (Axes) within one Figure, plotting two correlated arrays that are drawn from the discrete uniform distribution:

x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x, y))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))

ax1.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')

ax2.hist(data, bins=np.arange(data.min(), data.max()), label=('x', 'y'))
ax2.legend(loc=(0.65, 0.8))
ax2.set_title('Frequencies of $x$ and $y$')
ax2.yaxis.tick_right()

# %% [markdown]
# ---
#
# # EXERCISES :
#
# =============================================
# ## DESCRIPTIVE STATISTICS, LET'S PRACTICE
# ===============================================
#
#
#
# **Dataset:**
# friendsOnFB = [20, 63, 140, 165, 178, 63, 191, 364, 260, 234, 867, 480]
# np.asarray(friendsOnFB)
#
#
#
# ### 1) Frequency statistics:
# num_bins = 10
# bin_width = 40
#
# hist, edges = np.histogram(
#     friendsOnFB,
#     num_bins,
#     range=(0, bin_width*num_bins))
#
# hist, edges
#
#
# You can also calculate the frequency as:
# hist/len(friendsOnFB)
#
#
# *** It should work, but in case problem with integer you can do: ***
# hist.astype(float)
#
#
#
#
#
#
#
#
# ### 2) Calculate:
# #total size
# #max
# #min
# #range
#
#
#
#
#
#
# ### 3) Define a module to calculate the mean Ora andiamo a Descriptive statistics:
# #mean
# def mean(x):
#     return sum(x)/len(x)
#
#
# mean(friendsOnFB)
#
#
#
# #Now define modules to calculate (NOT USE NUMPY!):
# #median
# #mode
#
#
#
# SUGGESTIONS:
# median:  ====> suggestions: sorted(x) ;
# n % 2 == 0 if even
# n % 2 == 1 if odd
#
#
#
# mode: check at this page
# https://docs.python.org/2/library/collections.html
#
#
#
#
#
#
#
#
#
#
# ### 4) make a plot , on x = number of friends, on y np.arange(numero amici)
#
# add a vertical line corresponding to the mean, median, mode
#
# suggestion===> plt.vlines(x, ymin, ymax, colors='green', linestyles='solid')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### SPOILER ALERT, do not look...
#
#
#
#
# *solution*
# x = np.arange(len(friendsOnFB))
# plt.scatter(friendsOnFB,x)
# plt.vlines(mean(friendsOnFB), min(x), max(x)+1, colors='green', linestyles='solid')
# plt.vlines(median(friendsOnFB), min(x), max(x)+1, colors='blue', linestyles='solid')
# a = mode(friendsOnFB)[0]
# plt.vlines(a[0], min(x), max(x)+1, colors='red', linestyles='solid')
#
#
#
#
#
#
#
#
#
#
# ### 5) Variance:
#
# make a module for the variance
#
#
#
#
#
#
#
#
#
# def variance (x):
#     num=[]
#     for xi in x:
#         num_i = (xi-mean(x))
#         num.append(num_i*num_i)
#     return sum(num)/len(num)-1
#
#
# variance(friendsOnFB)
#
#
#
# #### 6) standard deviation (also with modulo)
# #suggestion===> math.sqrt(x)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### 7) Covariance  (make a module)
#
# friendsOnFB = [20, 63, 140, 165, 178, 63, 191, 364, 260, 234, 867, 480]
# minutes = [10, 115, 270, 130, 80, 162, 230, 105, 245, 480, 320, 280]
#
#
#
#
#
#
#
#
#
#
#
#
# def covariance (x,y):
#     num=[]
#     i=0
#     for xi in x:
#         num_i = (xi-mean(x))
#         num_j = (y[i]-mean(y))
#         num.append(num_i*num_j)
#         i+=1
#     return sum(num)/len(num)-1
#
#
# covariance(friendsOnFB, minutes)
#
#
#
#
#
# ### 8) correlation
#
#
#
#
#
#
#
#
#
#
#
#
#
# def correlation (x,y):
#     return covariance(x,y)/ (standard_dev(x)*  standard_dev(y))
#
#
#
# correlation(friendsOnFB, minutes)
#
#
#
#
#
#
#
#
# ### in numpy....
#
#
# x= friendsOnFB
# y = minutes
#
# X = np.vstack((x,y))
# print(np.cov(X))
#
# np.corrcoef(x,y)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Part II : Seaboarn
#
# <img src="seabornLogo.png">
#
#
# *On Seaborn’s official website, they state:
#
# If matplotlib “tries to make easy things easy and hard things possible”, seaborn tries to make a well-defined set of hard things easy too*

# %%
#note that seaborn is built ON matplotlib and sometimes it needs it
import seaborn as sns

#We apply the default default seaborn theme, scaling, and color palette.
sns.set()
#load dataset
tips = sns.load_dataset("tips")
#print (tips)

sns.relplot(x="total_bill", y="tip", col="time",
            hue="smoker", style="smoker", size="size",
            data=tips);
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# This particular plot shows the relationship between five variables in the tips dataset. Three are numeric, and two are categorical. Two numeric variables (total_bill and tip) determined the position of each point on the axes, and the third (size) determined the size of each point. One categorical variable split the dataset onto two different axes (facets), and the other determined the color and shape of each point.
#
# All of this was accomplished using a single call to the seaborn function relplot(). Notice how we only provided the names of the variables in the dataset and the roles that we wanted them to play in the plot. Unlike when using matplotlib directly, it wasn’t necessary to translate the variables into parameters of the visualization

# %% [markdown]
# # Estimation Error bars

# %%
#When statistical values are estimated, 
#seaborn will use bootstrapping to compute confidence intervals and draw error bars representing the uncertainty of the estimate.

fmri = sns.load_dataset("fmri")
print (fmri)
sns.relplot(x="timepoint", y="signal", col="region",
            hue="event", style="event",
            kind="line", data=fmri);
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# 5         s9         18  stim  parietal -0.103513
# 6         s8         18  stim  parietal -0.064408
# 7         s7         18  stim  parietal -0.060526
# 8         s6         18  stim  parietal -0.007029
# 9         s5         18  stim  parietal -0.040557
# 10        s4         18  stim  parietal -0.048812
# 11        s3         18  stim  parietal -0.047148
# 12        s2         18  stim  parietal -0.086623
# 13        s1         18  stim  parietal -0.046659
# 14        s0         18  stim  parietal -0.075570
# 15       s13         17  stim  parietal -0.008265
# 16       s12         17  stim  parietal -0.088512
# 17        s7          9  stim  parietal  0.058897
# ...

# %%
#it is also possible to enhance a scatterplot to include a linear regression model (and its uncertainty) using lmplot():

sns.lmplot(x="total_bill", y="tip", col="time", hue="smoker",
           data=tips);
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Alternately, you could use kernel density estimation to represent the underlying distribution that the points are sampled from:

sns.catplot(x="day", y="total_bill", hue="smoker", kind="violin", split=True, data=tips);
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Or you could show the only mean value and its confidence interval within each nested category:

sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="bar", data=tips);
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Visualize dataset structure

iris = sns.load_dataset("iris")
sns.jointplot(x="sepal_length", y="petal_length", data=iris);
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Part III: Bokeh
#
# ![testo](https://www.fullstackpython.com/img/logos/bokeh.jpg)
#
#
# *Bokeh is an interactive visualization library that targets modern web browsers for presentation. Its goal is to provide elegant, concise construction of versatile graphics, and to extend this capability with high-performance interactivity over very large or streaming datasets. *

# %%
# Standard imports 

from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83f9ac91-998c-4876-a6e8-bd638502cb7e">Loading BokehJS ...</span>
#     </div>

# %%
# Plot a complex chart with intearctive hover in a few lines of code

from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.autompg import autompg_clean as df
from bokeh.transform import factor_cmap

df.cyl = df.cyl.astype(str)
df.yr = df.yr.astype(str)

group = df.groupby(by=['cyl', 'mfr'])
source = ColumnDataSource(group)

p = figure(plot_width=800, plot_height=300, title="Mean MPG by # Cylinders and Manufacturer",
           x_range=group, toolbar_location=None, tools="")

p.xgrid.grid_line_color = None
p.xaxis.axis_label = "Manufacturer grouped by # Cylinders"
p.xaxis.major_label_orientation = 1.2

index_cmap = factor_cmap('cyl_mfr', palette=['#2b83ba', '#abdda4', '#ffffbf', '#fdae61', '#d7191c'], 
                         factors=sorted(df.cyl.unique()), end=1)

p.vbar(x='cyl_mfr', top='mpg_mean', width=1, source=source,
       line_color="white", fill_color=index_cmap, 
       hover_line_color="darkgrey", hover_fill_color=index_cmap)

p.add_tools(HoverTool(tooltips=[("MPG", "@mpg_mean"), ("Cyl, Mfr", "@cyl_mfr")]))

show(p)
# Out:
#   <div class="bk-root" id="7370a7a4-ba2d-40d5-b1f6-a625534c7d23"></div>

# %%
# Create and deploy interactive data applications

from IPython.display import IFrame
IFrame('https://demo.bokeh.org/sliders', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://demo.bokeh.org/sliders"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
# create a new plot with a title
p = figure(plot_width=400, plot_height=400)
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"

p.circle([1,2,3,4,5], [2,5,8,2,7], size=10)

show(p)
# Out:
#   <div class="bk-root" id="327b42ad-0160-437c-885b-0a9630f468cc"></div>

# %%
# EXERCISE Create a plot of your own and customize several plot-level properties
